# %%
import matplotlib.pyplot as plt

# Data
prices = [14292.2, 12858.9, 11467.5, 9241.1, 8559.6, 11073.5, 9704.3, 11402.3,
          8762.0, 7874.9, 8547.4, 6938.2, 6905.7, 8004.4, 8923.1, 9352.4,
          9853.5, 8459.5, 8245.1, 7361.3, 7646.6, 7515.8, 6505.8, 6167.3, 
          6398.9, 6765.5, 6254.8, 7408.7, 8234.1, 7014.3, 6231.6, 6379.1,
          6734.8, 7189.6, 6184.3, 6519.0, 6729.6, 6603.9, 6596.3, 6321.7,
          6572.2, 6494.2, 6386.2, 6427.1, 5621.8, 3920.4, 4196.2, 3430.4,
          3228.7, 3964.4, 3706.8, 3785.4, 3597.2, 3677.8, 3570.9, 3502.5,
          3661.4, 3616.8, 4120.4, 3823.1, 3944.3, 4006.4, 4002.5, 4111.8,
          5046.2, 5051.8, 5290.2, 5265.9, 5830.9, 7190.3, 7262.6, 8027.4,
          8545.7, 7901.4, 8812.5, 10721.7, 11906.5, 11268.0, 11364.9, 10826.7,
          9492.1, 10815.7, 11314.5, 10218.1, 10131.0, 9594.4, 10461.1, 10337.3,
          9993.0, 8208.5, 8127.3, 8304.4, 7957.3, 9230.6, 9300.6, 8804.5,
          8497.3, 7324.1, 7546.6, 7510.9, 7080.8, 7156.2, 7321.5, 7376.8]

# Bagi data tahun 2018 dan 2019
prices_2018 = prices[:54]
prices_2019 = prices[54:]

# Buat plot
plt.figure(figsize=(10, 6))
plt.plot(prices_2018, label='2018', marker='o')
plt.plot(prices_2019, label='2019', marker='o')

# Tambahkan label dan judul
plt.xlabel('Minggu ke-')
plt.ylabel('Harga Bitcoin')
plt.title('Perubahan Harga Bitcoin per Minggu (2018 dan 2019)')
plt.legend()

# Tampilkan plot
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
candy_names = ['Kit Kat', 'Snickers', 'Milky Way', 'Toblerone', 'Twix']
candy_counts = [52, 39, 78, 13, 78]

# Langkah 1: Hitung total jumlah permen dalam kantong
total_candies = sum(candy_counts)

# Langkah 2: Hitung persentase peluang untuk setiap jenis permen
peluang = [count / total_candies for count in candy_counts]

# Langkah 3: Gambarkan diagram lingkaran
plt.figure(figsize=(8, 8))
plt.pie(peluang, labels=candy_names, autopct='%1.1f%%', startangle=140, colors=['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0'])
plt.title('Persentase Peluang Memilih Permen Snickers')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
dessert_sales = {
  'Lava Cake': 14,
  'Mousse': 5,
  'Chocolate Cake': 12,
  'Ice Cream': 19,
  'Truffles': 6,
  'Brownie': 8,
  'Chocolate Chip Cookie': 12,
  'Chocolate Pudding': 9,
  'Souffle': 10,
  'Chocolate Cheesecake': 17,
  'Chocolate Chips': 2,
  'Fudge': 9,
  'Mochi': 13,
}

# Sorting desserts based on sales (descending order)
sorted_desserts = dict(sorted(dessert_sales.items(), key=lambda item: item[1], reverse=True))

# Menampilkan 3 makanan penutup yang harus disingkirkan
unpopular_desserts = list(sorted_desserts.keys())[-3:]

# Menggambar diagram batang
plt.figure(figsize=(10, 6))
plt.bar(sorted_desserts.keys(), sorted_desserts.values(), color='skyblue')
plt.xlabel('Makanan Penutup')
plt.ylabel('Jumlah Penjualan')
plt.title('Popularitas Relatif Makanan Penutup')
plt.xticks(rotation=45, ha='right')  # Rotasi label sumbu x
plt.show()

# Menampilkan 3 makanan penutup yang harus disingkirkan
print("Makanan penutup yang harus disingkirkan:", unpopular_desserts)
# Out:
# Makanan penutup yang harus disingkirkan: ['Truffles', 'Mousse', 'Chocolate Chips']

# %%
import matplotlib.pyplot as plt

# Data
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
hours = list(range(24))
cpu_usage = [
  [2, 2, 4, 2, 4, 1, 1, 4, 4, 12, 22, 23, 45, 9, 33, 56, 23, 40, 21, 6, 6, 2, 2, 3], # Monday
  [1, 2, 3, 2, 3, 2, 3, 2, 7, 22, 45, 44, 33, 9, 23, 19, 33, 56, 12, 2, 3, 1, 2, 2], # Tuesday
  [2, 3, 1, 2, 4, 4, 2, 2, 1, 2, 5, 31, 54, 7, 6, 34, 68, 34, 49, 6, 6, 2, 2, 3], # Wednesday
  [1, 2, 3, 2, 4, 1, 2, 4, 1, 17, 24, 18, 41, 3, 44, 42, 12, 36, 41, 2, 2, 4, 2, 4], # Thursday
  [4, 1, 2, 2, 3, 2, 5, 1, 2, 12, 33, 27, 43, 8, 38, 53, 29, 45, 39, 3, 1, 1, 3, 4], # Friday
  [2, 3, 1, 2, 2, 5, 2, 8, 4, 2, 3, 1, 5, 1, 2, 3, 2, 6, 1, 2, 2, 1, 4, 3], # Saturday
  [1, 2, 3, 1, 1, 3, 4, 2, 3, 1, 2, 2, 5, 3, 2, 1, 4, 2, 45, 26, 33, 2, 2, 1], # Sunday
]

# Membuat heatmap tanpa seaborn
plt.figure(figsize=(12, 8))
heatmap = plt.pcolor(cpu_usage, cmap='YlGnBu', edgecolors='w', linewidths=2)

# Menambahkan nilai di dalam sel
for i in range(len(days)):
    for j in range(len(hours)):
        plt.text(j + 0.5, i + 0.5, str(cpu_usage[i][j]), ha='center', va='center')

# Menambahkan label
plt.xticks([0.5 + i for i in range(len(hours))], hours)
plt.yticks([0.5 + i for i in range(len(days))], days)
plt.title('Penggunaan CPU Selama Seminggu')
plt.xlabel('Jam')
plt.ylabel('Hari')

# Menambahkan colorbar
cbar = plt.colorbar(heatmap, label='Penggunaan CPU')

# Menampilkan plot
plt.show()

# Jawaban pertanyaan-pertanyaan
# 1. Jam berapa pekerja biasanya makan siang?
print("Jam makan siang biasanya pada jam:", hours[cpu_usage[0].index(max(cpu_usage[0]))])

# # 2. Apakah pekerja tersebut bekerja pada akhir pekan?
# weekend_usage = sum(cpu_usage[-2:])  # Menghitung total penggunaan pada Sabtu dan Minggu
# print("Pekerja bekerja pada akhir pekan:", "Ya" if weekend_usage > 0 else "Tidak")

# 3. Pada hari apa pekerja mulai bekerja pada komputer mereka pada malam hari?
night_start_day = days[cpu_usage.index(max(cpu_usage, key=lambda x: x[18]))]
print("Pekerja mulai bekerja pada malam hari pada hari:", night_start_day)
# Out:
# Jam makan siang biasanya pada jam: 15
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/acer/machineLearning/pertemuan2/latihan.ipynb Cell 4 line 4
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/acer/machineLearning/pertemuan2/latihan.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=39'>40</a> print("Jam makan siang biasanya pada jam:", hours[cpu_usage[0].index(max(cpu_usage[0]))])
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/acer/machineLearning/pertemuan2/latihan.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=41'>42</a> # 2. Apakah pekerja tersebut bekerja pada akhir pekan?
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/acer/machineLearning/pertemuan2/latihan.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=42'>43</a> weekend_usage = sum(cpu_usage[-2:])  # Menghitung total penggunaan pada Sabtu dan Minggu
# ...
